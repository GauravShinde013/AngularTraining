# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravShinde013/AngularTraining/blob/master/Action_Detection_using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install mediapipe
# !pip install tensorflow

# %%
import os
import cv2
import numpy as np
import pandas as pd
import mediapipe as mp
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Initialize MediaPipe Holistic model
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# Path to the dataset
DATA_PATH = '/content/drive/MyDrive/ISL_CSLRT_Corpus/Frames_Sentence_Level'
CSV_PATH = '/content/drive/MyDrive/ISL_CSLRT_Corpus/corpus_csv_files/ISL_CSLRT_Corpus_frame_details.csv'

# Define actions (this should be dynamic based on your dataset)
actions = np.array(os.listdir(DATA_PATH))
# Limit to a subset of sentences for quicker testing
LIMIT = 10
actions = actions[:LIMIT]
# Videos are going to be 30 frames in length
sequence_length = 30

# Function to extract keypoints using MediaPipe
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# Function to process images and extract keypoints
def process_images(action, sequence_folders, sequence_length=30):
    sequences = []
    labels = []

    for subfolder in sequence_folders:
        subfolder_path = os.path.join(DATA_PATH, action, subfolder)
        frames = sorted(os.listdir(subfolder_path))
        window = []

        for frame_name in frames:
            frame_path = os.path.join(subfolder_path, frame_name)
            frame_path = frame_path.replace("\\", "/")
            if os.path.exists(frame_path):
                image = cv2.imread(frame_path)
                if image is None:
                    print(f"Failed to load image {frame_path}")
                    continue
                image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                # Process the image to extract keypoints
                with mp_holistic.Holistic(static_image_mode=True) as holistic:
                    results = holistic.process(image_rgb)
                    keypoints = extract_keypoints(results)
                    window.append(keypoints)
            else:
                print(f"Frame {frame_path} does not exist.")

        if len(window) >= sequence_length:
            for start in range(0, len(window) - sequence_length + 1, sequence_length):
                sequences.append(window[start:start + sequence_length])
                labels.append(action)
        elif len(window) > 0:
            sequences.append(window[:sequence_length] + [np.zeros_like(window[0])] * (sequence_length - len(window)))
            labels.append(action)

    return sequences, labels

# Read the CSV file
df = pd.read_csv(CSV_PATH)
df['Frames path'] = df['Frames path'].str.replace('\\', '/')
df['Sentence'] = df['Sentence'].str.lower().str.replace(' ', '_')

# Process the dataset
all_sequences = []
all_labels = []
for action in actions:
    action_path = os.path.join(DATA_PATH, action)
    sequence_folders = [folder for folder in os.listdir(action_path) if os.path.isdir(os.path.join(action_path, folder))]

    # Process images for the current action
    sequences, labels = process_images(action, sequence_folders)
    if sequences:  # Only add non-empty sequences
        all_sequences.extend(sequences)  # Flattened directly here
        all_labels.extend(labels)

# Convert to NumPy arrays
X = np.array(all_sequences)
label_map = {label: num for num, label in enumerate(actions)}
y = to_categorical([label_map[label] for label in all_labels], num_classes=len(actions))

# Print the shapes of the arrays to verify the data
print(X.shape)
print(y.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# (14, 30, 1662)
# (14, 2)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (13, 30, 1662), y_train shape: (13, 2)
# X_test shape: (1, 30, 1662), y_test shape: (1, 2)

# %% [markdown]
# # Build and Train LSTM Neural Network

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import TensorBoard

# Define the model
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# Compile the model
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Print the model summary
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 596642 (2.28 MB)
# Trainable params: 596642 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Tensor board

# %%
# Setup TensorBoard
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# Train the model
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 6s 6s/step - loss: 0.6873 - categorical_accuracy: 0.4615
# Epoch 2/200
# 1/1 [==============================] - 0s 249ms/step - loss: 0.6101 - categorical_accuracy: 0.6923
# Epoch 3/200
# 1/1 [==============================] - 0s 221ms/step - loss: 5.0316 - categorical_accuracy: 0.4615
# Epoch 4/200
# 1/1 [==============================] - 0s 227ms/step - loss: 1.4314 - categorical_accuracy: 0.1538
# Epoch 5/200
# 1/1 [==============================] - 0s 227ms/step - loss: 4.7694 - categorical_accuracy: 0.5385
# Epoch 6/200
# 1/1 [==============================] - 0s 229ms/step - loss: 1.6813 - categorical_accuracy: 0.5385
# Epoch 7/200
# 1/1 [==============================] - 0s 219ms/step - loss: 4.9715 - categorical_accuracy: 0.6154
# Epoch 8/200
# 1/1 [==============================] - 0s 171ms/step - loss: 0.6008 - categorical_accuracy: 0.6923
# Epoch 9/200
# 1/1 [==============================] - 0s 242ms/step - loss: 0.5751 - categorical_accuracy: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.6372 - categorical_accuracy: 0.7692
# Epoch 11/200
# 1/1 [==============================] - 0s 254ms/step - loss: 0.4787 - categorical_accuracy: 0.8462
# Epoch 12/200
# 1/1 [==============================] - 0s 250ms/step - loss: 2.0077 - categorical_accuracy: 0.3077
# Epoch 13/200
# 1/1 [==============================] - 0s 220ms/step - loss: 0.5408 - categorical_accuracy: 0.7692
# Epoch 14/200
# 1/1 [==============================] - 0s 150ms/step - loss: 0.4470 - categorical_accuracy: 0.8462
# Epoch 15/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.3178 - categorical_accuracy: 0.9231
# Epoch 16/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.4271 - categorical_accuracy: 0.9231
# Epoch 17/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.7852 - categorical_accuracy: 0.6923
# Epoch 18/200
# 1/1 [==============================] - 0s 110ms/step - loss: 1.1268 - categorical_accuracy: 0.6154
# Epoch 19/200
# 1/1 [==============================] - 0s 104ms/step - loss: 0.2868 - categorical_accuracy: 0.7692
# Epoch 20/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.2091 - categorical_accuracy: 0.9231
# Epoch 21/200
# 1/1 [==============================] - 0s 108ms/step - loss: 0.2245 - categorical_accuracy: 0.8462
# Epoch 22/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.3955 - categorical_accuracy: 0.9231
# Epoch 23/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.9883 - categorical_accuracy: 0.8462
# Epoch 24/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.9541 - categorical_accuracy: 0.8462
# Epoch 25/200
# 1/1 [==============================] - 0s 143ms/step - loss: 1.6237 - categorical_accuracy: 0.6154
# Epoch 26/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6166 - categorical_accuracy: 0.7692
# Epoch 27/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.2644 - categorical_accuracy: 0.8462
# Epoch 28/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.6611 - categorical_accuracy: 0.8462
# Epoch 29/200
# 1/1 [==============================] - 0s 120ms/step - loss: 1.4605 - categorical_accuracy: 0.9231
# Epoch 30/200
# 1/1 [==============================] - 0s 115ms/step - loss: 3.0723 - categorical_accuracy: 0.5385
# Epoch 31/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.3952 - categorical_accuracy: 0.8462
# Epoch 32/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.6243 - categorical_accuracy: 0.7692
# Epoch 33/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.5146 - categorical_accuracy: 0.7692
# Epoch 34/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2289 - categorical_accuracy: 0.8462
# Epoch 35/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.3369 - categorical_accuracy: 0.9231
# Epoch 36/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.2695 - categorical_accuracy: 0.9231
# Epoch 37/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.1996 - categorical_accuracy: 0.9231
# Epoch 38/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.
200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.1381 - categorical_accuracy: 0.9231
# Epoch 141/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.1527 - categorical_accuracy: 0.8462
# Epoch 142/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1677 - categorical_accuracy: 0.8462
# Epoch 143/200
# 1/1 [==============================] - 0s 132ms/step - loss: 0.1391 - categorical_accuracy: 0.9231
# Epoch 144/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.2023 - categorical_accuracy: 0.9231
# Epoch 145/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.1271 - categorical_accuracy: 0.9231
# Epoch 146/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1371 - categorical_accuracy: 0.9231
# Epoch 147/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.1310 - categorical_accuracy: 0.9231
# Epoch 148/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.1096 - categorical_accuracy: 0.9231
# Epoch 149/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.1010 - categorical_accuracy: 0.9231
# Epoch 150/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1409 - categorical_accuracy: 0.9231
# Epoch 151/200
# 1/1 [==============================] - 0s 206ms/step - loss: 0.1021 - categorical_accuracy: 0.9231
# Epoch 152/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1363 - categorical_accuracy: 0.8462
# Epoch 153/200
# 1/1 [==============================] - 0s 166ms/step - loss: 0.1634 - categorical_accuracy: 0.8462
# Epoch 154/200
# 1/1 [==============================] - 0s 234ms/step - loss: 0.1736 - categorical_accuracy: 0.8462
# Epoch 155/200
# 1/1 [==============================] - 0s 233ms/step - loss: 0.1618 - categorical_accuracy: 0.8462
# Epoch 156/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1379 - categorical_accuracy: 0.8462
# Epoch 157/200
# 1/1 [==============================] - 0s 348ms/step - loss: 0.1161 - categorical_accuracy: 0.9231
# Epoch 158/200
# 1/1 [==============================] - 0s 234ms/step - loss: 0.1008 - categorical_accuracy: 0.9231
# Epoch 159/200
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0951 - categorical_accuracy: 0.9231
# Epoch 160/200
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0906 - categorical_accuracy: 0.9231
# Epoch 161/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0820 - categorical_accuracy: 0.9231
# Epoch 162/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0749 - categorical_accuracy: 0.9231
# Epoch 163/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0705 - categorical_accuracy: 0.9231
# Epoch 164/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0707 - categorical_accuracy: 0.9231
# Epoch 165/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0733 - categorical_accuracy: 0.9231
# Epoch 166/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0710 - categorical_accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0633 - categorical_accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0557 - categorical_accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0529 - categorical_accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0500 - categorical_accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0454 - categorical_accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0425 - categorical_accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0384 - categorical_accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0348 - categorical_accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0309 - categorical_accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0268 - categorical_accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0228 - categorical_accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0189 - categorical_accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0149 - categorical_accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 230ms/step - loss: 0.0110 - categorical_accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0071 - categorical_accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 228ms/step - loss: 3.1648 - categorical_accuracy: 0.9231
# Epoch 185/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0099 - categorical_accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 235ms/step - loss: 0.0499 - categorical_accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0734 - categorical_accuracy: 0.9231
# Epoch 189/200
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0823 - categorical_accuracy: 0.9231
# Epoch 190/200
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0765 - categorical_accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0750 - categorical_accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 225ms/step - loss: 0.0869 - categorical_accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 245ms/step - loss: 0.0968 - categorical_accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0978 - categorical_accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0873 - categorical_accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0693 - categorical_accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 231ms/step - loss: 0.0552 - categorical_accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0479 - categorical_accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0426 - categorical_accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0372 - categorical_accuracy: 1.0000

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")
# Out:
# 1/1 [==============================] - 1s 715ms/step - loss: 0.6601 - categorical_accuracy: 1.0000
# Test loss: 0.6601467132568359, Test accuracy: 1.0

# %%
# Make predictions
res = model.predict(X_test)

# Print predictions and true labels
for i in range(len(X_test)):
    print(f"Predicted: {actions[np.argmax(res[i])]}, True: {actions[np.argmax(y_test[i])]}")
# Out:
# 1/1 [==============================] - 0s 406ms/step
# Predicted: bring water for me, True: bring water for me

# %%
# %%capture
pip install gtts

# %%
from gtts import gTTS
import os
import numpy as np

# %%
# Function to convert text to speech
def text_to_speech(text, lang='en'):
    tts = gTTS(text=text, lang=lang)
    filename = "output.mp3"
    tts.save(filename)
    os.system(f"mpg321 {filename}")

# Make predictions
res = model.predict(X_test)

# Print predictions and true labels
for i in range(len(X_test)):
    predicted_text = actions[np.argmax(res[i])]
    true_text = actions[np.argmax(y_test[i])]
    print(f"Predicted: {predicted_text}, True: {true_text}")

    # Convert the predicted text to speech
    text_to_speech(predicted_text)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# Predicted: bring water for me, True: bring water for me

# %%
import cv2
import os

VIDEO_PATH = '/content/drive/MyDrive/ISL_CSLRT_Corpus/Videos_Sentence_Level'
FRAME_PATH = '/content/drive/MyDrive/ISL_CSLRT_Corpus/Extracted_Frames'
LIMIT = 2  # Limit to a subset of sentences for quicker testing

def extract_frames_from_videos(video_path, frame_path, limit):
    if not os.path.exists(frame_path):
        os.makedirs(frame_path)

    sentences = os.listdir(video_path)[:limit]

    for sentence in sentences:
        sentence_path = os.path.join(video_path, sentence)
        if os.path.isdir(sentence_path):
            for video_file in os.listdir(sentence_path):
                video_file_path = os.path.join(sentence_path, video_file)
                cap = cv2.VideoCapture(video_file_path)
                frame_count = 0
                sentence_frame_path = os.path.join(frame_path, sentence, video_file.split('.')[0])

                if not os.path.exists(sentence_frame_path):
                    os.makedirs(sentence_frame_path)

                while cap.isOpened():
                    ret, frame = cap.read()
                    if not ret:
                        break
                    frame_file_path = os.path.join(sentence_frame_path, f"frame_{frame_count}.jpg")
                    cv2.imwrite(frame_file_path, frame)
                    frame_count += 1

                cap.release()

# Extract frames from videos
extract_frames_from_videos(VIDEO_PATH, FRAME_PATH, LIMIT)

# %%
def process_frames(frame_path, sequence_length=30):
    sequences = []
    labels = []

    for sentence in os.listdir(frame_path):
        sentence_path = os.path.join(frame_path, sentence)
        if not os.path.isdir(sentence_path):
            continue
        for video_folder in os.listdir(sentence_path):
            video_folder_path = os.path.join(sentence_path, video_folder)
            if not os.path.isdir(video_folder_path):
                continue
            frames = sorted(os.listdir(video_folder_path))
            window = []

            for frame_name in frames:
                frame_path = os.path.join(video_folder_path, frame_name)
                frame_path = frame_path.replace("\\", "/")  # Ensure correct path format
                if os.path.exists(frame_path):
                    image = cv2.imread(frame_path)
                    if image is None:
                        print(f"Failed to load image {frame_path}")
                        continue
                    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                    # Process the image to extract keypoints
                    with mp_holistic.Holistic(static_image_mode=True) as holistic:
                        results = holistic.process(image_rgb)
                        keypoints = extract_keypoints(results)
                        window.append(keypoints)
                else:
                    print(f"Frame {frame_path} does not exist.")

            if len(window) >= sequence_length:
                for start in range(0, len(window) - sequence_length + 1, sequence_length):
                    sequences.append(window[start:start + sequence_length])
                    labels.append(sentence)
            elif len(window) > 0:
                sequences.append(window[:sequence_length] + [np.zeros_like(window[0])] * (sequence_length - len(window)))
                labels.append(sentence)

    return sequences, labels

# Process the extracted frames
all_sequences, all_labels = process_frames(FRAME_PATH)

# Convert to NumPy arrays
X = np.array(all_sequences)
label_map = {label: num for num, label in enumerate(set(all_labels))}
y = to_categorical([label_map[label] for label in all_labels], num_classes=len(label_map))

# Print the shapes of the arrays to verify the data
print(X.shape)
print(y.shape)
# Out:
# (18, 30, 1662)
# (18, 1)

# %% [markdown]
# # Split the Data and Train the Model

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)

# Define the model (as done previously)
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(len(label_map), activation='softmax'))

# Compile the model
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1260: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 1/1 [==============================] - 6s 6s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 2/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 3/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 4/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 5/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 6/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 8/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 12/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 13/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 196ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 237ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 233ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 231ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 207ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 167ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 198ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 203ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 236ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 209ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 182ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 211ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 245ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# 1/1 [==============================] - 0s 448ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Test loss: 0.0, Test accuracy: 1.0

# %%
from pytube import YouTube

def download_video(youtube_url, save_path):
    yt = YouTube(youtube_url)
    ys = yt.streams.get_highest_resolution()
    ys.download(save_path)

# Example usage
youtube_url = 'https://www.youtube.com/watch?v=your_video_id'
save_path = '/path/to/save/video'
download_video(youtube_url, save_path)

# %%
def extract_frames_from_video(video_file_path, frame_output_path):
    cap = cv2.VideoCapture(video_file_path)
    frame_count = 0

    if not os.path.exists(frame_output_path):
        os.makedirs(frame_output_path)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame_file_path = os.path.join(frame_output_path, f"frame_{frame_count}.jpg")
        cv2.imwrite(frame_file_path, frame)
        frame_count += 1

    cap.release()

# Example usage
video_file_path = '/path/to/save/video/your_video_file.mp4'
frame_output_path = '/path/to/save/frames'
extract_frames_from_video(video_file_path, frame_output_path)

# %%
def process_video_frames(frame_path, sequence_length=30):
    frames = sorted(os.listdir(frame_path))
    sequences = []
    window = []

    for frame_name in frames:
        frame_file_path = os.path.join(frame_path, frame_name)
        frame_file_path = frame_file_path.replace("\\", "/")  # Ensure correct path format
        if os.path.exists(frame_file_path):
            image = cv2.imread(frame_file_path)
            if image is None:
                print(f"Failed to load image {frame_file_path}")
                continue
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Process the image to extract keypoints
            with mp_holistic.Holistic(static_image_mode=True) as holistic:
                results = holistic.process(image_rgb)
                keypoints = extract_keypoints(results)
                window.append(keypoints)
        else:
            print(f"Frame {frame_file_path} does not exist.")

    if len(window) >= sequence_length:
        for start in range(0, len(window) - sequence_length + 1, sequence_length):
            sequences.append(window[start:start + sequence_length])
    elif len(window) > 0:
        sequences.append(window[:sequence_length] + [np.zeros_like(window[0])] * (sequence_length - len(window)))

    return sequences

# Example usage
processed_sequences = process_video_frames(frame_output_path)
X_new_video = np.array(processed_sequences)

# %%
# Make predictions on the new video frames
predictions = model.predict(X_new_video)

# Map predictions to actions
predicted_actions = [label_map[np.argmax(pred)] for pred in predictions]

print(predicted_actions)

# %%
# Function to convert text to speech
def text_to_speech(text, lang='en'):
    tts = gTTS(text=text, lang=lang)
    filename = "output.mp3"
    tts.save(filename)
    os.system(f"mpg321 {filename}")

# Convert predicted actions to speech
for action in predicted_actions:
    print(f"Predicted: {action}")
    text_to_speech(action)
